# %%
def carbon_footprint():
    print("🌱 Carbon Footprint Calculator 🌱")
    km = float(input("Enter kilometers traveled per week: "))
    electricity = float(input("Enter monthly electricity use (kWh): "))
    diet = input("Enter your diet type (veg/non-veg): ").lower()

    # simple assumptions
    travel_emission = km * 0.12 * 4  # kg CO2 per month
    electricity_emission = electricity * 0.92
    diet_emission = 100 if diet == 'non-veg' else 60

    total = travel_emission + electricity_emission + diet_emission
    print(f"\nYour estimated monthly carbon footprint: {total:.2f} kg CO2")

    if total > 300:
        print("⚠ Try carpooling, switching to LED bulbs, and eating more plants!")
    else:
        print("✅ Great job! You’re living sustainably!")

carbon_footprint()
# Out:
# 🌱 Carbon Footprint Calculator 🌱
# Enter kilometers traveled per week:  100
# Enter monthly electricity use (kWh):  600
# Enter your diet type (veg/non-veg):  veg
# Your estimated monthly carbon footprint: 660.00 kg CO2
# ⚠ Try carpooling, switching to LED bulbs, and eating more plants!
